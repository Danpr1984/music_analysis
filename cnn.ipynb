# %% [markdown]
# ### TEST 86% ACCURACY

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score

DATA_PATH = "/Users/danielporras/Musica/music_x/data.json"

def add_noise(data):
    noise_factor = 0.003 * np.random.randn(*data.shape)
    data_noise = data + noise_factor
    return data_noise

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["features"])
    y = np.array(data["labels"])

    from imblearn.over_sampling import SMOTE

    # Assume X is your feature matrix and y are your labels
    smote = SMOTE()
    X_resampled, y_resampled = smote.fit_resample(X, y)
    
    # Add noise to a random subset of the data
    indices = np.random.randint(0, X.shape[0], size=int(X.shape[0] * 0.12))
    X[indices] = add_noise(X[indices])
    
    return X, y

def prepare_datasets(test_size, validation_size):
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # Reshape the data to 4D (num_samples, num_features, 1, 1) for Conv2D
    X_train = X_train[..., np.newaxis, np.newaxis]
    X_validation = X_validation[..., np.newaxis, np.newaxis]
    X_test = X_test[..., np.newaxis, np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005):
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())  # Move batch normalization after activation
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(7, activation='softmax'))

    return model

if __name__ == "__main__":
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Adjust dropout and regularization parameters
    model = build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005)

    optimiser = tf.keras.optimizers.RMSprop(learning_rate=0.0003)

    # Use learning rate scheduler
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-6)
    
    # Use early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        batch_size=32, epochs=100, callbacks=[lr_scheduler, early_stopping])

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

# Compute predictions
    y_prob = model.predict(X_test)
    y_pred = np.argmax(y_prob, axis=1)

    # Create confusion matrix
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1, 2, 3, 4, 5, 6, 7])

    # Display confusion matrix
    cm_df = pd.DataFrame(cm, index=[f'True {i}' for i in range(8)], columns=[f'Predicted {i}' for i in range(8)])

    print("Confusion Matrix:")
    print(cm_df)

    # Rest of the code for precision, F1 score, classification report, and loss curves
    precision = precision_score(y_test, y_pred, average='weighted')
    print(f'Precision: {precision}')

    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'F1 Score: {f1}')

    report = classification_report(y_test, y_pred)
    print(report)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.show()
    
model.save('/Users/danielporras/Musica/music_x/best_model.h5')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 26, 1, 64)         640
#
#  max_pooling2d_20 (MaxPooli  (None, 13, 1, 64)         0
#  ng2D)
#
#  batch_normalization_30 (Ba  (None, 13, 1, 64)         256
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 13, 1, 128)        73856
#
#  max_pooling2d_21 (MaxPooli  (None, 7, 1, 128)         0
#  ng2D)
#
#  batch_normalization_31 (Ba  (None, 7, 1, 128)         512
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 7, 1, 256)         295168
#
#  max_pooling2d_22 (MaxPooli  (None, 4, 1, 256)         0
#  ng2D)
#
#  batch_normalization_32 (Ba  (None, 4, 1, 256)         1024
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 4, 1, 512)         1180160
#
#  max_pooling2d_23 (MaxPooli  (None, 2, 1, 512)         0
#  ng2D)
#
#  batch_normalization_33 (Ba  (None, 2, 1, 512)         2048
#  tchNormalization)
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_15 (Dense)            (None, 512)               524800
#
#  batch_normalization_34 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense
100
# 23/23 [==============================] - 1s 33ms/step - loss: 0.8778 - accuracy: 0.8794 - val_loss: 0.9387 - val_accuracy: 0.8380 - lr: 3.0000e-05
# Epoch 31/100
# 23/23 [==============================] - 1s 35ms/step - loss: 0.8746 - accuracy: 0.8864 - val_loss: 0.9849 - val_accuracy: 0.8156 - lr: 3.0000e-05
# Epoch 32/100
# 23/23 [==============================] - 1s 24ms/step - loss: 0.8726 - accuracy: 0.8920 - val_loss: 0.9715 - val_accuracy: 0.8212 - lr: 3.0000e-05
# Epoch 33/100
# 23/23 [==============================] - 1s 22ms/step - loss: 0.8722 - accuracy: 0.8962 - val_loss: 1.0046 - val_accuracy: 0.8268 - lr: 3.0000e-05
# Epoch 34/100
# 23/23 [==============================] - 1s 23ms/step - loss: 0.8488 - accuracy: 0.8934 - val_loss: 0.9640 - val_accuracy: 0.7989 - lr: 3.0000e-05
# Epoch 35/100
# 23/23 [==============================] - 1s 24ms/step - loss: 0.8128 - accuracy: 0.8990 - val_loss: 0.9786 - val_accuracy: 0.8268 - lr: 3.0000e-05
# Epoch 36/100
# 23/23 [==============================] - 1s 24ms/step - loss: 0.8159 - accuracy: 0.8990 - val_loss: 0.9712 - val_accuracy: 0.8268 - lr: 3.0000e-06
# Epoch 37/100
# 23/23 [==============================] - 1s 23ms/step - loss: 0.8203 - accuracy: 0.9018 - val_loss: 0.9626 - val_accuracy: 0.8268 - lr: 3.0000e-06
# Epoch 38/100
# 23/23 [==============================] - 1s 24ms/step - loss: 0.7947 - accuracy: 0.9116 - val_loss: 0.9589 - val_accuracy: 0.8268 - lr: 3.0000e-06
# Epoch 39/100
# 23/23 [==============================] - 1s 25ms/step - loss: 0.7917 - accuracy: 0.9004 - val_loss: 0.9537 - val_accuracy: 0.8268 - lr: 3.0000e-06
# Epoch 40/100
# 23/23 [==============================] - 1s 25ms/step - loss: 0.8070 - accuracy: 0.9018 - val_loss: 0.9486 - val_accuracy: 0.8268 - lr: 3.0000e-06
# 10/10 - 0s - loss: 0.9670 - accuracy: 0.8423 - 40ms/epoch - 4ms/step
#
# Test accuracy: 0.8422818779945374
# 10/10 [==============================] - 0s 3ms/step
# Confusion Matrix:
#         Predicted 0  Predicted 1  Predicted 2  Predicted 3  Predicted 4  \
# True 0           41            0            5            1            1
# True 1            4           26            2            2            5
# True 2            0            0           42            5            0
# True 3            5            0            1           28            0
# True 4            0            2            0            0           34
# True 5            0            0            0            0            0
# True 6            0            0            3            2            0
# True 7            0            0            0            0            0
#
#         Predicted 5  Predicted 6  Predicted 7
# True 0            0            0            0
# True 1            1            0            0
# True 2            1            1            0
# True 3            0            3            0
# True 4            0            0            0
# True 5           44            1            0
# True 6            2           36            0
# True 7            0            0            0
# Precision: 0.8463164472409895
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 129
#     126 precision = precision_score(y_test, y_pred, average='weighted')
#     127 print(f'Precision: {precision}')
# --> 129 f1 = f1_score(y_test, y_pred, average='weighted')
#     130 print(f'F1 Score: {f1}')
#     132 report = classification_report(y_test, y_pred)
#
# NameError: name 'f1_score' is not defined

# %% [markdown]
# ### H6 Model time shift data

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras import layers

DATA_PATH = "/Users/danielporras/Musica/music_x/data.json"

def add_noise(data):
    noise_factor = 0.002 * np.random.randn(*data.shape)
    data_noise = data + noise_factor
    return data_noise

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["features"])
    y = np.array(data["labels"])
    
    # Add noise to a random subset of the data
    indices = np.random.randint(0, X.shape[0], size=int(X.shape[0] * 0.12))
    X[indices] = add_noise(X[indices])
    
    return X, y

def prepare_datasets(test_size, validation_size):
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # Reshape the data to 4D (num_samples, num_features, 1, 1) for Conv2D
    X_train = X_train[..., np.newaxis, np.newaxis]
    X_validation = X_validation[..., np.newaxis, np.newaxis]
    X_test = X_test[..., np.newaxis, np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005):
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())  # Move batch normalization after activation
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(8, activation='softmax'))

    return model

if __name__ == "__main__":
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Adjust dropout and regularization parameters
    model = build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005)

    optimiser = tf.keras.optimizers.RMSprop(learning_rate=0.0003)

    # Use learning rate scheduler
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-6)
    
    # Use early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        batch_size=32, epochs=100, callbacks=[lr_scheduler, early_stopping])

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # Plotting the training and validation loss curves
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.show()

model.save('/Users/danielporras/Musica/music_x/best_model.h6')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 26, 1, 64)         640
#
#  max_pooling2d_15 (MaxPooli  (None, 13, 1, 64)         0
#  ng2D)
#
#  batch_normalization_19 (Ba  (None, 13, 1, 64)         256
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 13, 1, 128)        73856
#
#  max_pooling2d_16 (MaxPooli  (None, 7, 1, 128)         0
#  ng2D)
#
#  batch_normalization_20 (Ba  (None, 7, 1, 128)         512
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 7, 1, 256)         295168
#
#  max_pooling2d_17 (MaxPooli  (None, 4, 1, 256)         0
#  ng2D)
#
#  batch_normalization_21 (Ba  (None, 4, 1, 256)         1024
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 4, 1, 512)         1180160
#
#  max_pooling2d_18 (MaxPooli  (None, 2, 1, 512)         0
#  ng2D)
#
#  batch_normalization_22 (Ba  (None, 2, 1, 512)         2048
#  tchNormalization)
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_12 (Dense)            (None, 512)               524800
#
#  batch_normalization_23 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  batch_normalization_24 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_14 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 2214920 (8.45 MB)
# Trainable params: 2211464 (8.44 MB)
# Non-trainable params: 3456 (13.50 KB)
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 1s 31ms/step - loss: 2.9656 - accuracy: 0.2794 - val_loss: 2.5837 - val_accuracy: 0.1765 - lr: 3.0000e-04
# Epoch 2/100
# 26/26 [==============================] - 1s 27ms/step - loss: 2.5322 - accuracy: 0.3738 - val_loss: 2.5907 - val_accuracy: 0.1471 - lr: 3.0000e-04
# Epoch 3/100
# 26/26 [==============================] - 1s 28ms/step - loss: 2.3335 - accuracy: 0.4020 - val_loss: 2.5951 - val_accuracy: 0.1716 - lr: 3.0000e-04
100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.6432 - accuracy: 0.9252 - val_loss: 1.2288 - val_accuracy: 0.8137 - lr: 3.0000e-05
# Epoch 47/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.6469 - accuracy: 0.9265 - val_loss: 1.2237 - val_accuracy: 0.8284 - lr: 3.0000e-05
# Epoch 48/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.6714 - accuracy: 0.9228 - val_loss: 1.2182 - val_accuracy: 0.8088 - lr: 3.0000e-05
# Epoch 49/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.6583 - accuracy: 0.9216 - val_loss: 1.2177 - val_accuracy: 0.8186 - lr: 3.0000e-05
# Epoch 50/100
# 26/26 [==============================] - 1s 26ms/step - loss: 0.6271 - accuracy: 0.9265 - val_loss: 1.2194 - val_accuracy: 0.8088 - lr: 3.0000e-06
# Epoch 51/100
# 26/26 [==============================] - 1s 27ms/step - loss: 0.6251 - accuracy: 0.9191 - val_loss: 1.2261 - val_accuracy: 0.8186 - lr: 3.0000e-06
# Epoch 52/100
# 26/26 [==============================] - 1s 29ms/step - loss: 0.6464 - accuracy: 0.9130 - val_loss: 1.2281 - val_accuracy: 0.8186 - lr: 3.0000e-06
# Epoch 53/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.6374 - accuracy: 0.9265 - val_loss: 1.2295 - val_accuracy: 0.8088 - lr: 3.0000e-06
# Epoch 54/100
# 26/26 [==============================] - 1s 25ms/step - loss: 0.6209 - accuracy: 0.9314 - val_loss: 1.2323 - val_accuracy: 0.8088 - lr: 3.0000e-06
# 11/11 - 0s - loss: 0.9126 - accuracy: 0.8765 - 58ms/epoch - 5ms/step
#
# Test accuracy: 0.8764705657958984
# INFO:tensorflow:Assets written to: /Users/danielporras/Musica/music_x/best_model.h6/assets
# INFO:tensorflow:Assets written to: /Users/danielporras/Musica/music_x/best_model.h6/assets

# %% [markdown]
# ### H5 Model

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.metrics import precision_score, f1_score, classification_report

DATA_PATH = "/Users/danielporras/Musica/music_x/data.json"

def add_noise(data):
    noise_factor = 0.002 * np.random.randn(*data.shape)
    data_noise = data + noise_factor
    return data_noise

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["features"])
    y = np.array(data["labels"])
    
    # Add noise to a random subset of the data
    indices = np.random.randint(0, X.shape[0], size=int(X.shape[0] * 0.11))
    X[indices] = add_noise(X[indices])
    
    return X, y

def prepare_datasets(test_size, validation_size):
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # Reshape the data to 4D (num_samples, num_features, 1, 1) for Conv2D
    X_train = X_train[..., np.newaxis, np.newaxis]
    X_validation = X_validation[..., np.newaxis, np.newaxis]
    X_test = X_test[..., np.newaxis, np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005):
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())  # Move batch normalization after activation
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(8, activation='softmax'))

    return model

if __name__ == "__main__":
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Adjust dropout and regularization parameters
    model = build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005)

    optimiser = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.0003)
    # Use learning rate scheduler
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-6)
    
    # Use early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        batch_size=32, epochs=100, callbacks=[lr_scheduler, early_stopping])

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
    
    # Compute predictions
    y_prob = model.predict(X_test)
    y_pred = np.argmax(y_prob, axis=1)

    # Compute precision
    precision = precision_score(y_test, y_pred, average='weighted')
    print(f'Precision: {precision}')

    # Compute F1 score
    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'F1 Score: {f1}')

    # Print a detailed classification report
    report = classification_report(y_test, y_pred)
    print(report)

    # Plotting the training and validation loss curves
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_19 (Conv2D)          (None, 26, 1, 64)         640
#
#  max_pooling2d_19 (MaxPooli  (None, 13, 1, 64)         0
#  ng2D)
#
#  batch_normalization_25 (Ba  (None, 13, 1, 64)         256
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 13, 1, 128)        73856
#
#  max_pooling2d_20 (MaxPooli  (None, 7, 1, 128)         0
#  ng2D)
#
#  batch_normalization_26 (Ba  (None, 7, 1, 128)         512
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 7, 1, 256)         295168
#
#  max_pooling2d_21 (MaxPooli  (None, 4, 1, 256)         0
#  ng2D)
#
#  batch_normalization_27 (Ba  (None, 4, 1, 256)         1024
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 4, 1, 512)         1180160
#
#  max_pooling2d_22 (MaxPooli  (None, 2, 1, 512)         0
#  ng2D)
#
#  batch_normalization_28 (Ba  (None, 2, 1, 512)         2048
#  tchNormalization)
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_15 (Dense)            (None, 512)               524800
#
#  batch_normalization_29 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  batch_normalization_30 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 2214920 (8.45 MB)
# Trainable params: 2211464 (8.44 MB)
# Non-trainable params: 3456 (13.50 KB)
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 1s 29ms/step - loss: 3.1126 - accuracy: 0.2635 - val_loss: 2.5564 - val_accuracy: 0.2843 - lr: 3.0000e-04
# Epoch 2/100
# 26/26 [==============================] - 1s 24ms/step - loss: 2.6329 - accuracy: 0.3456 - val_loss: 2.5796 - val_accuracy: 0.0784 - lr: 3.0000e-04
# Epoch 3/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.5389 - accuracy: 0.3689 - val_loss: 2.5314 - val_accuracy: 0.1765 - lr: 3.0000e-04
# Epoch 4/100
# 26/26 [==============================] - 1s 23ms/step - loss: 2.4147 - accuracy: 0.3811 - val_loss: 2.5016 - val_accuracy: 0.2647 - lr: 3.0000e-04
# Epoch 5/100
# 26/26 [==============================] - 1s 23ms/step - loss: 2.3457 - accuracy: 0.4093 - val_loss: 2.5792 - val_accuracy: 0.2059 - lr: 3.0000e-04
# Epoch 6/100
# 26/26 [==============================] - 1s 23ms/step - loss: 2.3128 - accuracy: 0.4338 - val_loss: 2.6007 - val_accuracy: 0.1765 - lr: 3.0000e-04
# Epoch 7/100
# 26/26 [==============================] - 1s 24ms/step - loss: 2.1371 - accuracy: 0.4461 - val_loss: 2.6503 - val_accuracy: 0.2010 - lr: 3.0000e-04
# Epoch 8/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.1648 - accuracy: 0.4387 - val_loss: 2.3526 - val_accuracy: 0.2059 - lr: 3.0000e-04
# Epoch 9/100
# 26/26 [==============================] - 1s 23ms/step - loss: 2.0393 - accuracy: 0.4902 - val_loss: 2.4336 - val_accuracy: 0.2696 - lr: 3.0000e-04
# Epoch 10/100
# 26/26 [==============================] - 1s 25ms/step - loss: 1
100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.7568 - accuracy: 0.8909 - val_loss: 0.9202 - val_accuracy: 0.8725 - lr: 3.0000e-05
# Epoch 33/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.7564 - accuracy: 0.8897 - val_loss: 0.9225 - val_accuracy: 0.8627 - lr: 3.0000e-05
# Epoch 34/100
# 26/26 [==============================] - 1s 25ms/step - loss: 0.7237 - accuracy: 0.9056 - val_loss: 0.9069 - val_accuracy: 0.8578 - lr: 3.0000e-05
# Epoch 35/100
# 26/26 [==============================] - 1s 25ms/step - loss: 0.7675 - accuracy: 0.8836 - val_loss: 0.9089 - val_accuracy: 0.8676 - lr: 3.0000e-05
# Epoch 36/100
# 26/26 [==============================] - 1s 25ms/step - loss: 0.7154 - accuracy: 0.9081 - val_loss: 0.9006 - val_accuracy: 0.8775 - lr: 3.0000e-05
# Epoch 37/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.7403 - accuracy: 0.8897 - val_loss: 0.9074 - val_accuracy: 0.8775 - lr: 3.0000e-05
# Epoch 38/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7169 - accuracy: 0.9032 - val_loss: 0.9184 - val_accuracy: 0.8725 - lr: 3.0000e-05
# Epoch 39/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7343 - accuracy: 0.8909 - val_loss: 0.9282 - val_accuracy: 0.8725 - lr: 3.0000e-05
# Epoch 40/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7250 - accuracy: 0.8909 - val_loss: 0.9132 - val_accuracy: 0.8676 - lr: 3.0000e-05
# Epoch 41/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.6955 - accuracy: 0.9093 - val_loss: 0.9148 - val_accuracy: 0.8627 - lr: 3.0000e-05
# Epoch 42/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.6668 - accuracy: 0.9142 - val_loss: 0.9151 - val_accuracy: 0.8578 - lr: 3.0000e-06
# Epoch 43/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.6869 - accuracy: 0.9056 - val_loss: 0.9152 - val_accuracy: 0.8578 - lr: 3.0000e-06
# Epoch 44/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7123 - accuracy: 0.8934 - val_loss: 0.9161 - val_accuracy: 0.8578 - lr: 3.0000e-06
# Epoch 45/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.6974 - accuracy: 0.9069 - val_loss: 0.9153 - val_accuracy: 0.8529 - lr: 3.0000e-06
# Epoch 46/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.7013 - accuracy: 0.9032 - val_loss: 0.9176 - val_accuracy: 0.8529 - lr: 3.0000e-06
# 11/11 - 0s - loss: 0.9518 - accuracy: 0.8588 - 44ms/epoch - 4ms/step
#
# Test accuracy: 0.8588235378265381
# 11/11 [==============================] - 0s 3ms/step
# Precision: 0.863429515745692
# F1 Score: 0.8551419874422359
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        42
#            1       0.96      0.80      0.87        54
#            2       0.84      0.97      0.90        38
#            3       0.74      0.93      0.82        40
#            4       0.98      0.96      0.97        49
#            5       0.89      1.00      0.94        49
#            6       0.66      0.66      0.66        29
#            7       0.81      0.56      0.67        39
#
#     accuracy                           0.86       340
#    macro avg       0.85      0.85      0.84       340
# weighted avg       0.86      0.86      0.86       340
# /Users/danielporras/Musica/new_env_3_10/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import load_model

# Load the model
loaded_model = load_model('/Users/danielporras/Musica/music_x/best_model.h5')

# Get the output layer
output_layer = loaded_model.layers[-1]

# Print the number of units in the output layer
print(output_layer.units)
# Out:
# 8

# %%
from tensorflow.keras.models import load_model

# Load the model
loaded_model = load_model('/Users/danielporras/Musica/music_x/best_model.h5')

# %% [markdown]
# ### Test with different data base

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras import layers

DATA_PATH = "/Users/danielporras/Musica/music_x/data_shifted.json"

def add_noise(data):
    noise_factor = 0.002 * np.random.randn(*data.shape)
    data_noise = data + noise_factor
    return data_noise

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["features"])
    y = np.array(data["labels"])
    
    # Add noise to a random subset of the data
    indices = np.random.randint(0, X.shape[0], size=int(X.shape[0] * 0.12))
    X[indices] = add_noise(X[indices])
    
    return X, y

def prepare_datasets(test_size, validation_size):
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # Reshape the data to 4D (num_samples, num_features, 1, 1) for Conv2D
    X_train = X_train[..., np.newaxis, np.newaxis]
    X_validation = X_validation[..., np.newaxis, np.newaxis]
    X_test = X_test[..., np.newaxis, np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005):
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())  # Move batch normalization after activation
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(8, activation='softmax'))

    return model

if __name__ == "__main__":
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Adjust dropout and regularization parameters
    model = build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005)

    optimiser = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.0003)
    
    # Use learning rate scheduler
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-6)
    
    # Use early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        batch_size=32, epochs=100, callbacks=[lr_scheduler, early_stopping])

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

        # Compute predictions
    y_prob = model.predict(X_test)
    y_pred = np.argmax(y_prob, axis=1)

    # Compute precision
    precision = precision_score(y_test, y_pred, average='weighted')
    print(f'Precision: {precision}')

    # Compute F1 score
    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'F1 Score: {f1}')

    # Print a detailed classification report
    report = classification_report(y_test, y_pred)
    print(report)

    # Plotting the training and validation loss curves
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 26, 1, 64)         640
#
#  max_pooling2d_23 (MaxPooli  (None, 13, 1, 64)         0
#  ng2D)
#
#  batch_normalization_31 (Ba  (None, 13, 1, 64)         256
#  tchNormalization)
#
#  conv2d_24 (Conv2D)          (None, 13, 1, 128)        73856
#
#  max_pooling2d_24 (MaxPooli  (None, 7, 1, 128)         0
#  ng2D)
#
#  batch_normalization_32 (Ba  (None, 7, 1, 128)         512
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 7, 1, 256)         295168
#
#  max_pooling2d_25 (MaxPooli  (None, 4, 1, 256)         0
#  ng2D)
#
#  batch_normalization_33 (Ba  (None, 4, 1, 256)         1024
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 4, 1, 512)         1180160
#
#  max_pooling2d_26 (MaxPooli  (None, 2, 1, 512)         0
#  ng2D)
#
#  batch_normalization_34 (Ba  (None, 2, 1, 512)         2048
#  tchNormalization)
#
#  flatten_6 (Flatten)         (None, 1024)              0
#
#  dense_18 (Dense)            (None, 512)               524800
#
#  batch_normalization_35 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 512)               0
#
#  dense_19 (Dense)            (None, 256)               131328
#
#  batch_normalization_36 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7289 - accuracy: 0.8995 - val_loss: 0.9168 - val_accuracy: 0.8775 - lr: 3.0000e-05
# Epoch 40/100
# 26/26 [==============================] - 1s 22ms/step - loss: 0.6993 - accuracy: 0.9093 - val_loss: 0.9099 - val_accuracy: 0.8725 - lr: 3.0000e-05
# Epoch 41/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7275 - accuracy: 0.9020 - val_loss: 0.9098 - val_accuracy: 0.8922 - lr: 3.0000e-05
# Epoch 42/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7127 - accuracy: 0.9069 - val_loss: 0.9085 - val_accuracy: 0.8873 - lr: 3.0000e-05
# Epoch 43/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.6938 - accuracy: 0.9056 - val_loss: 0.9294 - val_accuracy: 0.8725 - lr: 3.0000e-05
# Epoch 44/100
# 26/26 [==============================] - 1s 22ms/step - loss: 0.7001 - accuracy: 0.9179 - val_loss: 0.9277 - val_accuracy: 0.8725 - lr: 3.0000e-06
# Epoch 45/100
# 26/26 [==============================] - 1s 22ms/step - loss: 0.6862 - accuracy: 0.9154 - val_loss: 0.9266 - val_accuracy: 0.8775 - lr: 3.0000e-06
# Epoch 46/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.6843 - accuracy: 0.9203 - val_loss: 0.9263 - val_accuracy: 0.8725 - lr: 3.0000e-06
# Epoch 47/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7036 - accuracy: 0.9154 - val_loss: 0.9283 - val_accuracy: 0.8725 - lr: 3.0000e-06
# Epoch 48/100
# 26/26 [==============================] - 1s 24ms/step - loss: 0.7214 - accuracy: 0.9056 - val_loss: 0.9271 - val_accuracy: 0.8824 - lr: 3.0000e-06
# 11/11 - 0s - loss: 0.9155 - accuracy: 0.8706 - 46ms/epoch - 4ms/step
#
# Test accuracy: 0.8705882430076599
# 11/11 [==============================] - 0s 4ms/step
# Precision: 0.8871192120723251
# F1 Score: 0.8716814210243716
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90        31
#            1       0.98      0.80      0.88        50
#            2       0.87      0.94      0.90        48
#            3       0.95      0.82      0.88        44
#            4       0.88      0.95      0.91        39
#            5       0.96      0.90      0.93        49
#            6       0.65      0.91      0.76        34
#            7       0.91      0.71      0.80        45
#
#     accuracy                           0.87       340
#    macro avg       0.88      0.88      0.87       340
# weighted avg       0.89      0.87      0.87       340

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
import json

DATA_PATH = "/Users/danielporras/Musica/music_x/random_data.json"

def add_noise(data):
    noise_factor = 0.002 * np.random.randn(*data.shape)
    data_noise = data + noise_factor
    return data_noise

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["features"])
    y = np.array(data["labels"])
    
    # Add noise to a random subset of the data
    indices = np.random.randint(0, X.shape[0], size=int(X.shape[0] * 0.12))
    X[indices] = add_noise(X[indices])
    
    return X, y

def prepare_datasets(test_size, validation_size):
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # Reshape the data to 4D (num_samples, num_features, 1, 1) for Conv2D
    X_train = X_train[..., np.newaxis, np.newaxis]
    X_validation = X_validation[..., np.newaxis, np.newaxis]
    X_test = X_test[..., np.newaxis, np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

def build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005):
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())  # Move batch normalization after activation
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(8, activation='softmax'))

    return model

if __name__ == "__main__":
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Adjust dropout and regularization parameters
    model = build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005)

    optimiser = tf.keras.optimizers.RMSprop(learning_rate=0.0003)
    
    # Use learning rate scheduler
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-6)
    
    # Use early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        batch_size=32, epochs=100, callbacks=[lr_scheduler, early_stopping])

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # Compute predictions
    y_prob = model.predict(X_test)
    y_pred = np.argmax(y_prob, axis=1)

    # Create confusion matrix
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1, 2, 3, 4, 5, 6, 7])

    # Display confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1, 2, 3, 4, 5, 6, 7])
    disp.plot(cmap='Blues', values_format='d')

    plt.title('Confusion Matrix')
    plt.show()

    # Rest of the code for precision, F1 score, classification report, and loss curves
    precision = precision_score(y_test, y_pred, average='weighted')
    print(f'Precision: {precision}')

    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'F1 Score: {f1}')

    report = classification_report(y_test, y_pred)
    print(report)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.show()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 26, 1, 64)         640
#
#  max_pooling2d_8 (MaxPoolin  (None, 13, 1, 64)         0
#  g2D)
#
#  batch_normalization_12 (Ba  (None, 13, 1, 64)         256
#  tchNormalization)
#
#  conv2d_9 (Conv2D)           (None, 13, 1, 128)        73856
#
#  max_pooling2d_9 (MaxPoolin  (None, 7, 1, 128)         0
#  g2D)
#
#  batch_normalization_13 (Ba  (None, 7, 1, 128)         512
#  tchNormalization)
#
#  conv2d_10 (Conv2D)          (None, 7, 1, 256)         295168
#
#  max_pooling2d_10 (MaxPooli  (None, 4, 1, 256)         0
#  ng2D)
#
#  batch_normalization_14 (Ba  (None, 4, 1, 256)         1024
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 4, 1, 512)         1180160
#
#  max_pooling2d_11 (MaxPooli  (None, 2, 1, 512)         0
#  ng2D)
#
#  batch_normalization_15 (Ba  (None, 2, 1, 512)         2048
#  tchNormalization)
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 512)               524800
#
#  batch_normalization_16 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  batch_normalization_17 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 2214920 (8.45 MB)
# Trainable params: 2211464 (8.44 MB)
# Non-trainable params: 3456 (13.50 KB)
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 1s 28ms/step - loss: 3.3214 - accuracy: 0.2191 - val_loss: 2.5752 - val_accuracy: 0.1634 - lr: 3.0000e-04
# Epoch 2/100
# 26/26 [==============================] - 1s 24ms/step - loss: 2.7205 - accuracy: 0.3069 - val_loss: 2.5819 - val_accuracy: 0.1089 - lr: 3.0000e-04
# Epoch 3/100
# 26/26 [==============================] - 1s 23ms/step - loss: 2.6480 - accuracy: 0.3255 - val_loss: 2.5826 - val_accuracy: 0.1782 - lr: 3.0000e-04
# Epoch 4/100
# 26/26 [==============================] - 1s 23ms/step - loss: 2.5035 - accuracy: 0.3713 - val_loss: 2.6187 - val_accuracy: 0.1485 - lr: 3.0000e-04
# Epoch 5/100
100
# 26/26 [==============================] - 1s 25ms/step - loss: 0.7820 - accuracy: 0.9047 - val_loss: 1.6383 - val_accuracy: 0.7030 - lr: 3.0000e-06
# Epoch 47/100
# 26/26 [==============================] - 1s 23ms/step - loss: 0.7571 - accuracy: 0.9183 - val_loss: 1.6397 - val_accuracy: 0.6980 - lr: 3.0000e-06
# 11/11 - 0s - loss: 1.4995 - accuracy: 0.6825 - 49ms/epoch - 4ms/step
#
# Test accuracy: 0.6824925541877747
# 11/11 [==============================] - 0s 5ms/step
# Precision: 0.6963707353712172
# F1 Score: 0.6859640374382305
#               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75        46
#            1       0.73      0.67      0.70        36
#            2       0.59      0.61      0.60        31
#            3       0.75      0.75      0.75        51
#            4       0.77      0.82      0.79        44
#            5       0.68      0.64      0.66        44
#            6       0.78      0.60      0.68        48
#            7       0.43      0.59      0.50        37
#
#     accuracy                           0.68       337
#    macro avg       0.69      0.68      0.68       337
# weighted avg       0.70      0.68      0.69       337

# %% [markdown]
# ### Fine tune with sample weights

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import precision_score, f1_score, classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras import layers

DATA_PATH = "/Users/danielporras/Musica/music_x/data_shifted.json"

def add_noise(data):
    noise_factor = 0.002 * np.random.randn(*data.shape)
    data_noise = data + noise_factor
    return data_noise

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["features"])
    y = np.array(data["labels"])
    
    # Add noise to a random subset of the data
    indices = np.random.randint(0, X.shape[0], size=int(X.shape[0] * 0.12))
    X[indices] = add_noise(X[indices])
    
    return X, y

def prepare_datasets(test_size, validation_size):
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # Reshape the data to 4D (num_samples, num_features, 1, 1) for Conv2D
    X_train = X_train[..., np.newaxis, np.newaxis]
    X_validation = X_validation[..., np.newaxis, np.newaxis]
    X_test = X_test[..., np.newaxis, np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

def build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005):
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())  # Move batch normalization after activation
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(8, activation='softmax'))

    return model

if __name__ == "__main__":
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Calculate sample weights based on inverse class frequencies
    sample_weights = compute_sample_weight('balanced', y_train)
    sample_weight_dict = dict(enumerate(sample_weights))

    # Adjust dropout and regularization parameters
    model = build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005)

    optimiser = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.0003)
    
    # Use learning rate scheduler
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-6)
    
    # Use early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        batch_size=32, epochs=100, callbacks=[lr_scheduler, early_stopping], sample_weight=sample_weights)

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # Compute predictions
    y_prob = model.predict(X_test)
    y_pred = np.argmax(y_prob, axis=1)

    # Create confusion matrix
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1, 2, 3, 4, 5, 6, 7])

    # Display confusion matrix
    cm_df = pd.DataFrame(cm, index=[f'True {i}' for i in range(8)], columns=[f'Predicted {i}' for i in range(8)])

    print("Confusion Matrix:")
    print(cm_df)

    # Rest of the code for precision, F1 score, classification report, and loss curves
    precision = precision_score(y_test, y_pred, average='weighted')
    print(f'Precision: {precision}')

    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'F1 Score: {f1}')

    report = classification_report(y_test, y_pred)
    print(report)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 26, 1, 64)         640
#
#  max_pooling2d_20 (MaxPooli  (None, 13, 1, 64)         0
#  ng2D)
#
#  batch_normalization_30 (Ba  (None, 13, 1, 64)         256
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 13, 1, 128)        73856
#
#  max_pooling2d_21 (MaxPooli  (None, 7, 1, 128)         0
#  ng2D)
#
#  batch_normalization_31 (Ba  (None, 7, 1, 128)         512
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 7, 1, 256)         295168
#
#  max_pooling2d_22 (MaxPooli  (None, 4, 1, 256)         0
#  ng2D)
#
#  batch_normalization_32 (Ba  (None, 4, 1, 256)         1024
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 4, 1, 512)         1180160
#
#  max_pooling2d_23 (MaxPooli  (None, 2, 1, 512)         0
#  ng2D)
#
#  batch_normalization_33 (Ba  (None, 2, 1, 512)         2048
#  tchNormalization)
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_15 (Dense)            (None, 512)               524800
#
#  batch_normalization_34 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  batch_normalization_35 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 2214920 (8.45 MB)
# Trainable params: 2211464 (8.44 MB)
# Non-trainable params: 3456 (13.50 KB)
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 1s 30ms/step - loss: 2.8544 - accuracy: 0.2696 - val_loss: 2.5842 - val_accuracy: 0.1471 - lr: 3.0000e-04
# Epoch 2/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.4618 - accuracy: 0.3897 - val_loss: 2.5972 - val_accuracy: 0.1373 - lr: 3.0000e-04
# Epoch 3/100
# 26/26 [==============================] - 1s 24ms/step - loss: 2.2998 - accuracy: 0.4118 - val_loss: 2.6573 - val_accuracy: 0.1618 - lr: 3.0000e-04
# Epoch 4/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.2770 - accuracy: 0.3983 - val_loss: 2.6860 - val_accuracy: 0.1471 - lr: 3.0000e-04
# Epoch 5/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.1521 - accuracy: 0.4706 - val_loss: 2.6213 - val_accuracy: 0.1324 - lr: 3.0000e-04
# Epoch 6/100
# 26/26 [==============================] - 1s 26ms/step - loss: 2.0411 - accuracy: 0.5000 - val_loss: 2.7630 - val_accuracy: 0.1667 - lr: 3.0000e-04
# Epoch 7/100
# 26/26 [==============================] - 1s 24ms/step - loss: 1.8232 - accuracy: 0.5527 - val_loss: 2.6925 - val_accuracy: 0.1765 - lr: 3.0000e-05
# Epoch 8/100
# 26/26 [==============================] - 1s 24ms/step - loss: 1.7831 - accuracy: 0.5699 - val_loss: 2.6128 - val_accuracy: 0.1814 - lr: 3.0000e-05
# Epoch 9/100
# 26/26 [==============================] - 1s 25ms/step - loss: 1.6324 - accuracy: 0.6042 - val_loss: 2.5007 - val_accuracy: 0.2059 - lr: 3.0000e-05
# Epoch 10/100
# 26/26 [==============================] - 1s 24ms/step - loss: 1.5791 - accuracy: 0.6201 - val_loss: 2.3490 - val_accuracy: 0.2451 - lr: 3.0000e-05
# Epoch 11/100
# 26/26 [==============================] - 1s 25ms/step - loss: 1
100
# 26/26 [==============================] - 1s 28ms/step - loss: 0.7154 - accuracy: 0.9020 - val_loss: 1.0245 - val_accuracy: 0.8235 - lr: 1.0000e-06
# 11/11 - 0s - loss: 0.9601 - accuracy: 0.8588 - 42ms/epoch - 4ms/step
#
# Test accuracy: 0.8588235378265381
# 11/11 [==============================] - 0s 3ms/step
# Confusion Matrix:
#         Predicted 0  Predicted 1  Predicted 2  Predicted 3  Predicted 4  \
# True 0           37            0            0            2            0
# True 1            3           45            0            0            0
# True 2            0            1           41            0            0
# True 3            3            0            2           37            0
# True 4            1            0            3            0           47
# True 5            0            2            0            0            0
# True 6            0            0            1            2            0
# True 7            0            0            0            1            4
#
#         Predicted 5  Predicted 6  Predicted 7
# True 0            0            2            0
# True 1            0            0            0
# True 2            0            1            0
# True 3            0            0            0
# True 4            0            0            0
# True 5           36            0            0
# True 6            0           31            7
# True 7            2           11           18
# Precision: 0.8563304572634984
# F1 Score: 0.8549292252913664
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        41
#            1       0.94      0.94      0.94        48
#            2       0.87      0.95      0.91        43
#            3       0.88      0.88      0.88        42
#            4       0.92      0.92      0.92        51
#            5       0.95      0.95      0.95        38
#            6       0.69      0.76      0.72        41
#            7       0.72      0.50      0.59        36
#
#     accuracy                           0.86       340
#    macro avg       0.85      0.85      0.85       340
# weighted avg       0.86      0.86      0.85       340

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import precision_score, f1_score, classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras import layers

DATA_PATH = "/Users/danielporras/Musica/music_x/data_shifted.json"

def add_noise(data):
    noise_factor = 0.002 * np.random.randn(*data.shape)
    data_noise = data + noise_factor
    return data_noise

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["features"])
    y = np.array(data["labels"])
    
    # Add noise to a random subset of the data
    indices = np.random.randint(0, X.shape[0], size=int(X.shape[0] * 0.12))
    X[indices] = add_noise(X[indices])
    
    return X, y

def prepare_datasets(test_size, validation_size):
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # Reshape the data to 4D (num_samples, num_features, 1, 1) for Conv2D
    X_train = X_train[..., np.newaxis, np.newaxis]
    X_validation = X_validation[..., np.newaxis, np.newaxis]
    X_test = X_test[..., np.newaxis, np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

def build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005):
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())  # Move batch normalization after activation
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(8, activation='softmax'))

    return model

if __name__ == "__main__":
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Calculate sample weights based on inverse class frequencies
    sample_weights = compute_sample_weight('balanced', y_train)
    sample_weight_dict = dict(enumerate(sample_weights))

    # Adjust dropout and regularization parameters
    model = build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005)

    optimiser = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.0003)
    
    # Use learning rate scheduler
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-6)
    
    # Use early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        batch_size=32, epochs=100, callbacks=[lr_scheduler, early_stopping], sample_weight=sample_weights)

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # Compute predictions
    y_prob = model.predict(X_test)
    y_pred = np.argmax(y_prob, axis=1)

    # Create confusion matrix
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1, 2, 3, 4, 5, 6, 7])

    # Display confusion matrix in tabular format
    cm_df = pd.DataFrame(cm, index=[f'True {i}' for i in range(8)], columns=[f'Predicted {i}' for i in range(8)])

    print("Confusion Matrix:")
    print(cm_df)

    # Rest of the code for precision, F1 score, classification report, and loss curves
    precision = precision_score(y_test, y_pred, average='weighted')
    print(f'Precision: {precision}')

    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'F1 Score: {f1}')

    report = classification_report(y_test, y_pred)
    print(report)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 26, 1, 64)         640
#
#  max_pooling2d_24 (MaxPooli  (None, 13, 1, 64)         0
#  ng2D)
#
#  batch_normalization_36 (Ba  (None, 13, 1, 64)         256
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 13, 1, 128)        73856
#
#  max_pooling2d_25 (MaxPooli  (None, 7, 1, 128)         0
#  ng2D)
#
#  batch_normalization_37 (Ba  (None, 7, 1, 128)         512
#  tchNormalization)
#
#  conv2d_26 (Conv2D)          (None, 7, 1, 256)         295168
#
#  max_pooling2d_26 (MaxPooli  (None, 4, 1, 256)         0
#  ng2D)
#
#  batch_normalization_38 (Ba  (None, 4, 1, 256)         1024
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 4, 1, 512)         1180160
#
#  max_pooling2d_27 (MaxPooli  (None, 2, 1, 512)         0
#  ng2D)
#
#  batch_normalization_39 (Ba  (None, 2, 1, 512)         2048
#  tchNormalization)
#
#  flatten_6 (Flatten)         (None, 1024)              0
#
#  dense_18 (Dense)            (None, 512)               524800
#
#  batch_normalization_40 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 512)               0
#
#  dense_19 (Dense)            (None, 256)               131328
#
#  batch_normalization_41 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_20 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 2214920 (8.45 MB)
# Trainable params: 2211464 (8.44 MB)
# Non-trainable params: 3456 (13.50 KB)
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 1s 38ms/step - loss: 3.1296 - accuracy: 0.2304 - val_loss: 2.5940 - val_accuracy: 0.1471 - lr: 3.0000e-04
# Epoch 2/100
# 26/26 [==============================] - 1s 30ms/step - loss: 2.4349 - accuracy: 0.3787 - val_loss: 2.6098 - val_accuracy: 0.1422 - lr: 3.0000e-04
# Epoch 3/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.4592 - accuracy: 0.3897 - val_loss: 2.6162 - val_accuracy: 0.1569 - lr: 3.0000e-04
# Epoch 4/100
# 26/26 [==============================] - 1s 23ms/step - loss: 2.2678 - accuracy: 0.4252 - val_loss: 2.6362 - val_accuracy: 0.2157 - lr: 3.0000e-04
# Epoch 5/100
# 26/26 [==============================] - 1s 24ms/step - loss: 2.2940 - accuracy: 0.4167 - val_loss: 2.6683 - val_accuracy: 0.2647 - lr: 3.0000e-04
# Epoch 6/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.0427 - accuracy: 0.4865 - val_loss: 2.5381 - val_accuracy: 0.2941 - lr: 3.0000e-04
# Epoch 7/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.0911 - accuracy: 0.4988 - val_loss: 2.4391 - val_accuracy: 0.2941 - lr: 3.0000e-04
# Epoch 8/100
# 26/26 [==============================] - 1s 24ms/step - loss: 1.9634 - accuracy: 0.5123 - val_loss: 2.5277 - val_accuracy: 0.2941 - lr: 3.0000e-04
# Epoch 9/100
# 26/26 [==============================] - 1s 25ms/step - loss: 1
# True 4            0            2            0            0           39
# True 5            0            0            0            0            0
# True 6            3            0            2            1            0
# True 7            2            1            1            1            4
#
#         Predicted 5  Predicted 6  Predicted 7
# True 0            0            0            0
# True 1            0            0            0
# True 2            0            2            0
# True 3            0            0            3
# True 4            0            0            0
# True 5           39            0            4
# True 6            1           39            0
# True 7            1            7           16
# Precision: 0.848655511353423
# F1 Score: 0.8450427602186621
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        51
#            1       0.93      0.98      0.95        43
#            2       0.85      0.93      0.89        43
#            3       0.91      0.72      0.81        40
#            4       0.85      0.95      0.90        41
#            5       0.95      0.91      0.93        43
#            6       0.81      0.85      0.83        46
#            7       0.70      0.48      0.57        33
#
#     accuracy                           0.85       340
#    macro avg       0.85      0.84      0.84       340
# weighted avg       0.85      0.85      0.85       340

# %% [markdown]
# ### Add SMOTE to balance code

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import precision_score, f1_score, classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras import layers

DATA_PATH = "/Users/danielporras/Musica/music_x/random_data.json"

def add_noise(data):
    noise_factor = 0.002 * np.random.randn(*data.shape)
    data_noise = data + noise_factor
    return data_noise

def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["features"])
    y = np.array(data["labels"])
    
    # Use SMOTE to balance the dataset
    smote = SMOTE()
    X, y = smote.fit_resample(X.reshape(X.shape[0], -1), y)
    
    # Convert data["features"] to a numpy array before accessing its shape
    features_array = np.array(data["features"])
    X = X.reshape(X.shape[0], features_array.shape[1])
    
    # Add noise to a random subset of the data
    indices = np.random.randint(0, X.shape[0], size=int(X.shape[0] * 0.12))
    X[indices] = add_noise(X[indices])
    
    return X, y

# Rest of your code remains the same

def prepare_datasets(test_size, validation_size):
    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # Reshape the data to 4D (num_samples, num_features, 1, 1) for Conv2D
    X_train = X_train[..., np.newaxis, np.newaxis]
    X_validation = X_validation[..., np.newaxis, np.newaxis]
    X_test = X_test[..., np.newaxis, np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test

def build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005):
    model = tf.keras.Sequential()

    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Conv2D(512, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2), padding='same'))
    model.add(layers.BatchNormalization())

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())  # Move batch normalization after activation
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularizer)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(dropout_rate))

    model.add(layers.Dense(8, activation='softmax'))

    return model

if __name__ == "__main__":
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])

    # Calculate sample weights based on inverse class frequencies
    sample_weights = compute_sample_weight('balanced', y_train)
    sample_weight_dict = dict(enumerate(sample_weights))

    # Adjust dropout and regularization parameters
    model = build_model_v2(input_shape, dropout_rate=0.4, l2_regularizer=0.0005)

    optimiser = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.0003)
    
    # Use learning rate scheduler
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-6)
    
    # Use early stopping
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                        batch_size=32, epochs=100, callbacks=[lr_scheduler, early_stopping], sample_weight=sample_weights)

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # Compute predictions
    y_prob = model.predict(X_test)
    y_pred = np.argmax(y_prob, axis=1)

    # Create confusion matrix
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1, 2, 3, 4, 5, 6, 7])

    # Display confusion matrix in tabular format
    cm_df = pd.DataFrame(cm, index=[f'True {i}' for i in range(8)], columns=[f'Predicted {i}' for i in range(8)])

    print("Confusion Matrix:")
    print(cm_df)

    # Rest of the code for precision, F1 score, classification report, and loss curves
    precision = precision_score(y_test, y_pred, average='weighted')
    print(f'Precision: {precision}')

    f1 = f1_score(y_test, y_pred, average='weighted')
    print(f'F1 Score: {f1}')

    report = classification_report(y_test, y_pred)
    print(report)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')

    plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 26, 1, 64)         640
#
#  max_pooling2d_28 (MaxPooli  (None, 13, 1, 64)         0
#  ng2D)
#
#  batch_normalization_42 (Ba  (None, 13, 1, 64)         256
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 13, 1, 128)        73856
#
#  max_pooling2d_29 (MaxPooli  (None, 7, 1, 128)         0
#  ng2D)
#
#  batch_normalization_43 (Ba  (None, 7, 1, 128)         512
#  tchNormalization)
#
#  conv2d_30 (Conv2D)          (None, 7, 1, 256)         295168
#
#  max_pooling2d_30 (MaxPooli  (None, 4, 1, 256)         0
#  ng2D)
#
#  batch_normalization_44 (Ba  (None, 4, 1, 256)         1024
#  tchNormalization)
#
#  conv2d_31 (Conv2D)          (None, 4, 1, 512)         1180160
#
#  max_pooling2d_31 (MaxPooli  (None, 2, 1, 512)         0
#  ng2D)
#
#  batch_normalization_45 (Ba  (None, 2, 1, 512)         2048
#  tchNormalization)
#
#  flatten_7 (Flatten)         (None, 1024)              0
#
#  dense_21 (Dense)            (None, 512)               524800
#
#  batch_normalization_46 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_14 (Dropout)        (None, 512)               0
#
#  dense_22 (Dense)            (None, 256)               131328
#
#  batch_normalization_47 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 2214920 (8.45 MB)
# Trainable params: 2211464 (8.44 MB)
# Non-trainable params: 3456 (13.50 KB)
# _________________________________________________________________
# Epoch 1/100
# 26/26 [==============================] - 2s 42ms/step - loss: 2.9596 - accuracy: 0.2770 - val_loss: 2.5910 - val_accuracy: 0.1814 - lr: 3.0000e-04
# Epoch 2/100
# 26/26 [==============================] - 1s 27ms/step - loss: 2.4954 - accuracy: 0.3873 - val_loss: 2.5936 - val_accuracy: 0.1373 - lr: 3.0000e-04
# Epoch 3/100
# 26/26 [==============================] - 1s 25ms/step - loss: 2.3905 - accuracy: 0.4130 - val_loss: 2.6363 - val_accuracy: 0.1225 - lr: 3.0000e-04
# Epoch 4/100
# 26/26 [==============================] - 1s 24ms/step - loss: 2.2936 - accuracy: 0.4559 - val_loss: 2.5949 - val_accuracy: 0.1127 - lr: 3.0000e-04
# Epoch 5/100
# 26/26 [==============================] - 1s 27ms/step - loss: 2.2074 - accuracy: 0.4522 - val_loss: 2.5232 - val_accuracy: 0.2157 - lr: 3.0000e-04
# Epoch 6/100
# 26/26 [==============================] - 1s 26ms/step - loss: 2.0748 - accuracy: 0.4877 - val_loss: 2.5425 - val_accuracy: 0.1912 - lr: 3.0000e-04
# Epoch 7/100
# 26/26 [==============================] - 1s 28ms/step - loss: 1.9448 - accuracy: 0.5319 - val_loss: 2.4877 - val_accuracy: 0.2598 - lr: 3.0000e-04
# Epoch 8/100
# 11/11 - 0s - loss: 0.9280 - accuracy: 0.8559 - 50ms/epoch - 5ms/step
#
# Test accuracy: 0.8558823466300964
# 11/11 [==============================] - 0s 4ms/step
# Confusion Matrix:
#         Predicted 0  Predicted 1  Predicted 2  Predicted 3  Predicted 4  \
# True 0           43            0            0            2            2
# True 1            0           40            0            0            0
# True 2            0            0           37            0            0
# True 3            0            0            4           34            0
# True 4            0            4            0            0           37
# True 5            0            1            0            0            0
# True 6            0            0            0            0            0
# True 7            0            0            0            0            2
#
#         Predicted 5  Predicted 6  Predicted 7
# True 0            0            1            1
# True 1            0            0            0
# True 2            0            6            0
# True 3            3            0            2
# True 4            0            0            7
# True 5           42            1            0
# True 6            2           30            3
# True 7            0            8           28
# Precision: 0.8687796273266646
# F1 Score: 0.8580386735883454
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93        49
#            1       0.89      1.00      0.94        40
#            2       0.90      0.86      0.88        43
#            3       0.94      0.79      0.86        43
#            4       0.90      0.77      0.83        48
#            5       0.89      0.95      0.92        44
#            6       0.65      0.86      0.74        35
#            7       0.68      0.74      0.71        38
#
#     accuracy                           0.86       340
#    macro avg       0.86      0.86      0.85       340
# weighted avg       0.87      0.86      0.86       340

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

file_path = 'path_to_your_file'  # replace with your file path
file_size = os.path.getsize(file_path)

print(f"The size of the file is {file_size} bytes")

# %%
import os

def get_dir_size(start_path = '.'):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(start_path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            total_size += os.path.getsize(fp)
    return total_size

directory_size_bytes = get_dir_size('/Users/danielporras/Musica/music_import/Music')
directory_size_MB = directory_size_bytes * 1.0E-6
directory_size_GB = directory_size_bytes * 1.0E-9

print(f"The size of the directory is {directory_size_bytes} bytes, {directory_size_MB} MB, or {directory_size_GB} GB")
# Out:
# The size of the directory is 1838463027 bytes, 1838.463027 MB, or 1.8384630270000002 GB
